# %%
from keras.applications.vgg16 import VGG16
from quiver_engine import server

# %%
model = VGG16()
server.launch(model,input_folder="./sample_images",
              temp_folder=".tmp",port=8000)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 16:03:56.176790 4469433792 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0828 16:03:56.193742 4469433792 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0828 16:03:56.196126 4469433792 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0828 16:03:56.222756 4469433792 deprecation_wrapper.py:119] From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...
